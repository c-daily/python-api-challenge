# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_name = []
cloudiness = []
countries = []
date = []
humidity = []
lat = []
lng_list = []
temp = []
wind_speed = []
index_counter = 0
set_counter = 1

print("Beginning Data Retrieval ")
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="


# For each city name in cities list, do below things...
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        countries.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        temp.append(response['main']['temp_max'])
        wind_speed.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping to next one.")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 : ushuaia
# Processing Record 2 of Set 1 : albany
# Processing Record 3 of Set 1 : busselton
# Processing Record 4 of Set 1 : naze
# Processing Record 5 of Set 1 : gimli
# Processing Record 6 of Set 1 : carnarvon
# Processing Record 7 of Set 1 : ukiah
# Processing Record 8 of Set 1 : provideniya
# Processing Record 9 of Set 1 : rikitea
# Processing Record 10 of Set 1 : hermanus
# Processing Record 11 of Set 1 : barrow
# Processing Record 12 of Set 1 : port alfred
# Processing Record 13 of Set 1 : lagoa
# Processing Record 14 of Set 1 : dongsheng
# Processing Record 15 of Set 1 : batagay-alyta
# Processing Record 16 of Set 1 : basqal
# Processing Record 17 of Set 1 : atuona
# Processing Record 18 of Set 1 : cape town
# Processing Record 19 of Set 1 : mancora
# Processing Record 20 of Set 1 : la sarre
# Processing Record 21 of Set 1 : butaritari
# Processing Record 22 of Set 1 : ojinaga
# Processing Record 23 of Set 1 : ribeira grande
# Processing Record 24 of Set 1 : avarua
# Processing Record 25 of Set 1 : cidreira
# Processing Record 26 of Set 1 : coquimbo
# Processing Record 27 of Set 1 : punta arenas
# Processing Record 28 of Set 1 : new norfolk
# Processing Record 29 of Set 1 : seversk
# Processing Record 30 of Set 1 : hirara
# Processing Record 31 of Set 1 : lishui
# Processing Record 32 of Set 1 : sao filipe
# Processing Record 33 of Set 1 : miandrivazo
# Processing Record 34 of Set 1 : hilo
# Processing Record 35 of Set 1 : upernavik
# City not found. Skipping to next one.
# Processing Record 36 of Set 1 : komsomolskiy
# Processing Record 37 of Set 1 : unai
# Processing Record 38 of Set 1 : okha
# Processing Record 39 of Set 1 : maxixe
# Processing Record 40 of Set 1 : bluff
# Processing Record 41 of Set 1 : grindavik
# Processing Record 42 of Set 1 : kruisfontein
# Processing Record 43 of Set 1 : tecoanapa
# Processing Record 44 of Set 1 : jamestown
# City not found. Skipping to next one.
# Processing Record 45 of Set 1 : ostrovnoy
# Processing Record 46 of Set 1 : souillac
# Processing Record 47 of Set 1 : georgetown
# Processing Record 48 of Set 1 : nome
# Processing Record 49 of Set 1 : tacoronte
# Processing Record 50 of Set 1 : yellowknife
# Processing Record 0 of Set 2 : severo-kurilsk
# Processing Record 1 of Set 2 : constitucion
# Processing Record 2 of Set 2 : kokopo
# Processing Record 3 of Set 2 : hervey bay
# Processing Record 4 of Set 2 : fremont
# Processing Record 5 of Set 2 : dingle
# Processing Record 6 of Set 2 : victoria
# Processing Record 7 of Set 2 : amuntai
# Processing Record 8 of Set 2 : puerto ayora
# Processing Record 9 of Set 2 : tezu
# Processing Record 10 of Set 2 : chokurdakh
# Processing Record 11 of Set 2 : lorengau
# Processing Record 12 of Set 2 : ozinki
# Processing Record 13 of Set 2 : hasaki
# Processing Record 14 of Set 2 : muros
# Processing Record 15 of Set 2 : cherskiy
# Processing Record 16 of Set 2 : bethel
# Processing Record 17 of Set 2 : mar del plata
# Processing Record 18 of Set 2 : luganville
# Processing Record 19 of Set 2 : banda aceh
# Processing Record 20 of Set 2 : ripky
# Processing Record 21 of Set 2 : torbay
# Processing Record 22 of Set 2 : port lincoln
# Processing Record 23 of Set 2 : beira
# Processing Record 24 of Set 2 : mahibadhoo
# Processing Record 25 of Set 2 : bredasdorp
# Processing Record 26 of Set 2 : qaanaaq
# City not found. Skipping to next one.
# Processing Record 27 of Set 2 : manzanillo
# City not found. Skipping to next one.
# Processing Record 28 of Set 2 : anadyr
# Processing Record 29 of Set 2 : fortuna
# Processing Record 30 of Set 2 : rochegda
# Processing Record 31 of Set 2 : castro
# Processing Record 32 of Set 2 : pevek
# Processing Record 33 of Set 2 : qrendi
# Processing Record 34 of Set 2 : hamilton
# City not found. Skipping to next one.
# Processing Record 35 of Set 2 : san policarpo
# City not found. Skipping to next one.
# City not found. Skipping to next one.
# City not found. Skipping to next one.
# Processing Record 36 of Set 2 : aginskoye
# Processing Record 37 of Set 2 : terra santa
# Processing Record 38 of Set 2 : sao joao da barra
# Processing Record 39 of Set 2 : meulaboh
# Processing Record 40 of Set 2 : dikson
# Processing Record 41 of Set 2 : tuktoyaktuk
# City not found. Skipping to next one.
# Processing Record 42 of Set 2 : cabo san lucas
# Processing Record 43 of Set 2 : fukue
# Processing Record 44 of Set 2 : nouadhibou
# Processing Record 45 of Set 2 : chuy
# Processing Record 46 of Set 2 : linhares
# Processing Record 47 of Set 2 : nokaneng
# Processing Record 48 of Set 2 : te anau
# Processing Record 49 of Set 2 : lavrentiya
# Processing Record 50 of Set 2 : roura
# Processing Record 0 of Set 3 : seoul
# Processing Record 1 of Set 3 : srednekolymsk
# Processing Record 2 of Set 3 : loding
# Processing Record 3 of Set 3 : san cristobal
# Processing Record 4 of Set 3 : bongandanga
# Processing Record 5 of Set 3 : skibbereen
# Processing Record 6 of Set 3 : svetlyy
# Processing Record 7 of Set 3 : grand-santi
# Processing Record 8 of Set 3 : klaksvik
# Processing Record 9 of Set 3 : bridgwater
# Processing Record 10 of Set 3 : pacific grove
# Processing Record 11 of Set 3 : tarbes
# City not found. Skipping to next one.
# Processing Record 12 of Set 3 : saint anthony
# Processing Record 13 of Set 3 : yar-sale
# Processing Record 14 of Set 3 : saint-philippe
# Processing Record 15 of Set 3 : mackay
# Processing Record 16 of Set 3 : lompoc
# Processing Record 17 of Set 3 : hami
# Processing Record 18 of Set 3 : korla
# Processing Record 19 of Set 3 : alugan
# Processing Record 20 of Set 3 : ayan
# Processing Record 21 of Set 3 : sinnamary
# Processing Record 22 of Set 3 : malartic
# Processing Record 23 of Set 3 : hofn
# Processing Record 24 of Set 3 : kaitangata
# Processing Record 25 of Set 3 : khatanga
# Processing Record 26 of Set 3 : tuatapere
# Processing Record 27 of Set 3 : oranjemund
# Processing Record 28 of Set 3 : mount gambier
# Processing Record 29 of Set 3 : fairbanks
# Processing Record 30 of Set 3 : kattivakkam
# Processing Record 31 of Set 3 : saint-francois
# Processing Record 32 of Set 3 : namibe
# Processing Record 33 of Set 3 : longyearbyen
# Processing Record 34 of Set 3 : bonavista
# Processing Record 35 of Set 3 : kavaratti
# Processing Record 36 of Set 3 : gao
# Processing Record 37 of Set 3 : vaini
# Processing Record 38 of Set 3 : lebu
# Processing Record 39 of Set 3 : novyy urgal
# Processing Record 40 of Set 3 : hithadhoo
# Processing Record 41 of Set 3 : road town
# Processing Record 42 of Set 3 : mataura
# Processing Record 43 of Set 3 : port elizabeth
# Processing Record 44 of Set 3 : saskylakh
# Processing Record 45 of Set 3 : san jose
# Processing Record 46 of Set 3 : xingyi
# Processing Record 47 of Set 3 : husavik
# Processing Record 48 of Set 3 : zyryanka
# Processing Record 49 of Set 3 : thompson
# Processing Record 50 of Set 3 : hobart
# Processing Record 0 of Set 4 : puerto lumbreras
# City not found. Skipping to next one.
# City not found. Skipping to next one.
# Processing Record 1 of Set 4 : kerman
# Processing Record 2 of Set 4 : medeiros neto
# Processing Record 3 of Set 4 : thinadhoo
# Processing Record 4 of Set 4 : tasiilaq
# Processing Record 5 of Set 4 : camana
# Processing Record 6 of Set 4 : vikhorevka
# Processing Record 7 of Set 4 : pridonskoy
# City not found. Skipping to next one.
# Processing Record 8 of Set 4 : airai
# Processing Record 9 of Set 4 : picos
# Processing Record 10 of Set 4 : arraial do cabo
# Processing Record 11 of Set 4 : ossora
# Processing Record 12 of Set 4 : bambous virieux
# Processing Record 13 of Set 4 : omsukchan
# Processing Record 14 of Set 4 : kodiak
# Processing Record 15 of Set 4 : oga
# Processing Record 16 of Set 4 : alofi
# Processing Record 17 of Set 4 : kawalu
# Processing Record 18 of Set 4 : laguna
# Processing Record 19 of Set 4 : coihaique
# Processing Record 20 of Set 4 : champerico
# Processing Record 21 of Set 4 : cockburn town
# Processing Record 22 of Set 4 : geraldton
# Processing Record 23 of Set 4 : maceio
# Processing Record 24 of Set 4 : kushiro
# Processing Record 25 of Set 4 : marsa matruh
# Processing Record 26 of Set 4 : yarovoye
# Processing Record 27 of Set 4 : polyarnyy
# Processing Record 28 of Set 4 : sterling
# Processing Record 29 of Set 4 : padre bernardo
# Processing Record 30 of Set 4 : kinlochleven
# Processing Record 31 of Set 4 : meadow lake
# Processing Record 32 of Set 4 : rawson
# City not found. Skipping to next one.
# Processing Record 33 of Set 4 : gharo
# Processing Record 34 of Set 4 : grand gaube
# Processing Record 35 of Set 4 : san patricio
# Processing Record 36 of Set 4 : wawa
# Processing Record 37 of Set 4 : jaru
# Processing Record 38 of Set 4 : buala
# Processing Record 39 of Set 4 : osa
# Processing Record 40 of Set 4 : kargasok
# Processing Record 41 of Set 4 : tyrma
# Processing Record 42 of Set 4 : shelabolikha
# Processing Record 43 of Set 4 : marawi
# City not found. Skipping to next one.
# Processing Record 44 of Set 4 : camacha
# Processing Record 45 of Set 4 : taoudenni
# Processing Record 46 of Set 4 : cowansville
# Processing Record 47 of Set 4 : wanning
# Processing Record 48 of Set 4 : umm kaddadah
# Processing Record 49 of Set 4 : mahebourg
# Processing Record 50 of Set 4 : tautira
# Processing Record 0 of Set 5 : saurimo
# City not found. Skipping to next one.
# City not found. Skipping to next one.
# Processing Record 1 of Set 5 : nanortalik
# Processing Record 2 of Set 5 : teknaf
# Processing Record 3 of Set 5 : sao miguel do araguaia
# Processing Record 4 of Set 5 : ponta do sol
# Processing Record 5 of Set 5 : kapaa
# Processing Record 6 of Set 5 : guanare
# Processing Record 7 of Set 5 : viransehir
# Processing Record 8 of Set 5 : chaozhou
# Processing Record 9 of Set 5 : luderitz
# Processing Record 10 of Set 5 : touros
# City not found. Skipping to next one.
# Processing Record 11 of Set 5 : hermiston
# Processing Record 12 of Set 5 : san rafael
# Processing Record 13 of Set 5 : luba
# Processing Record 14 of Set 5 : kidal
# City not found. Skipping to next one.
# City not found. Skipping to next one.
# Processing Record 15 of Set 5 : shahdadkot
# Processing Record 16 of Set 5 : talnakh
# Processing Record 17 of Set 5 : ust-nera
# Processing Record 18 of Set 5 : clyde river
# Processing Record 19 of Set 5 : deputatskiy
# Processing Record 20 of Set 5 : russell
# Processing Record 21 of Set 5 : kholodnyy
# Processing Record 22 of Set 5 : minot
# Processing Record 23 of Set 5 : beringovskiy
# Processing Record 24 of Set 5 : noumea
# Processing Record 25 of Set 5 : snezhnogorsk
# Processing Record 26 of Set 5 : luanda
# Processing Record 27 of Set 5 : derzhavinsk
# Processing Record 28 of Set 5 : carmelo
# Processing Record 29 of Set 5 : puerto del rosario
# Processing Record 30 of Set 5 : bilibino
# Processing Record 31 of Set 5 : yangambi
# Processing Record 32 of Set 5 : sayyan
# Processing Record 33 of Set 5 : fara in sabina
# Processing Record 34 of Set 5 : avera
# Processing Record 35 of Set 5 : baghdad
# City not found. Skipping to next one.
# Processing Record 36 of Set 5 : tornio
# Processing Record 37 of Set 5 : flin flon
# Processing Record 38 of Set 5 : lahij
# Processing Record 39 of Set 5 : pirovskoye
# Processing Record 40 of Set 5 : kalmunai
# Processing Record 41 of Set 5 : goderich
# Processing Record 42 of Set 5 : ascension
# Processing Record 43 of Set 5 : khandyga
# Processing Record 44 of Set 5 : oistins
# Processing Record 45 of Set 5 : henties bay
# City not found. Skipping to next one.
# Processing Record 46 of Set 5 : ust-koksa
# Processing Record 47 of Set 5 : port blair
# Processing Record 48 of Set 5 : sitka
# City not found. Skipping to next one.
# Processing Record 49 of Set 5 : necochea
# Processing Record 50 of Set 5 : cururupu
# Processing Record 0 of Set 6 : broome
# Processing Record 1 of Set 6 : alice springs
# Processing Record 2 of Set 6 : shizunai
# Processing Record 3 of Set 6 : faanui
# Processing Record 4 of Set 6 : marsberg
# Processing Record 5 of Set 6 : ust-tsilma
# Processing Record 6 of Set 6 : muriae
# City not found. Skipping to next one.
# Processing Record 7 of Set 6 : troitsko-pechorsk
# Processing Record 8 of Set 6 : verkhnyaya inta
# Processing Record 9 of Set 6 : domanivka
# Processing Record 10 of Set 6 : launceston
# Processing Record 11 of Set 6 : norman wells
# Processing Record 12 of Set 6 : ilulissat
# Processing Record 13 of Set 6 : nassau
# Processing Record 14 of Set 6 : erzin
# Processing Record 15 of Set 6 : vanavara
# Processing Record 16 of Set 6 : kirakira
# Processing Record 17 of Set 6 : vanino
# Processing Record 18 of Set 6 : sistranda
# Processing Record 19 of Set 6 : novosheshminsk
# Processing Record 20 of Set 6 : san lorenzo
# City not found. Skipping to next one.
# Processing Record 21 of Set 6 : tuy hoa
# Processing Record 22 of Set 6 : olinda
# Processing Record 23 of Set 6 : bintulu
# Processing Record 24 of Set 6 : port lavaca
# Processing Record 25 of Set 6 : iwanai
# Processing Record 26 of Set 6 : hadejia
# Processing Record 27 of Set 6 : portland
# Processing Record 28 of Set 6 : odda
# Processing Record 29 of Set 6 : walvis bay
# Processing Record 30 of Set 6 : makat
# Processing Record 31 of Set 6 : caravelas
# Processing Record 32 of Set 6 : nishihara
# Processing Record 33 of Set 6 : ushtobe
# Processing Record 34 of Set 6 : sao francisco
# Processing Record 35 of Set 6 : havelock
# Processing Record 36 of Set 6 : raudeberg
# Processing Record 37 of Set 6 : galle
# Processing Record 38 of Set 6 : sohag
# Processing Record 39 of Set 6 : dundee
# Processing Record 40 of Set 6 : saint-pierre
# Processing Record 41 of Set 6 : sangareddi
# Processing Record 42 of Set 6 : dalby
# City not found. Skipping to next one.
# Processing Record 43 of Set 6 : araouane
# Processing Record 44 of Set 6 : los llanos de aridane
# Processing Record 45 of Set 6 : bridlington
# Processing Record 46 of Set 6 : libenge
# Processing Record 47 of Set 6 : pangnirtung
# Processing Record 48 of Set 6 : eisenstadt
# City not found. Skipping to next one.
# Processing Record 49 of Set 6 : neuquen
# Processing Record 50 of Set 6 : lata
# Processing Record 0 of Set 7 : nuuk
# Processing Record 1 of Set 7 : carinhanha
# Processing Record 2 of Set 7 : san quintin
# Processing Record 3 of Set 7 : hvolsvollur
# Processing Record 4 of Set 7 : esperance
# Processing Record 5 of Set 7 : morondava
# Processing Record 6 of Set 7 : marion
# City not found. Skipping to next one.
# Processing Record 7 of Set 7 : novobiryusinskiy
# Processing Record 8 of Set 7 : nikolskoye
# Processing Record 9 of Set 7 : comodoro rivadavia
# City not found. Skipping to next one.
# City not found. Skipping to next one.
# Processing Record 10 of Set 7 : marshall
# Processing Record 11 of Set 7 : brae
# Processing Record 12 of Set 7 : nabire
# Processing Record 13 of Set 7 : kavieng
# Processing Record 14 of Set 7 : bac lieu
# Processing Record 15 of Set 7 : waipawa
# Processing Record 16 of Set 7 : leningradskiy
# Processing Record 17 of Set 7 : yining
# Processing Record 18 of Set 7 : mastic beach
# Processing Record 19 of Set 7 : jiayuguan
# Processing Record 20 of Set 7 : porto novo
# Processing Record 21 of Set 7 : pak phanang
# Processing Record 22 of Set 7 : herat
# Processing Record 23 of Set 7 : nantucket
# Processing Record 24 of Set 7 : golden
# Processing Record 25 of Set 7 : manadhoo
# Processing Record 26 of Set 7 : iqaluit
# Processing Record 27 of Set 7 : cap malheureux
# Processing Record 28 of Set 7 : branistea
# Processing Record 29 of Set 7 : kamenka
# Processing Record 30 of Set 7 : paragominas
# Processing Record 31 of Set 7 : eyemouth
# City not found. Skipping to next one.
# Processing Record 32 of Set 7 : hobyo
# Processing Record 33 of Set 7 : yaan
# Processing Record 34 of Set 7 : nyurba
# Processing Record 35 of Set 7 : coahuayana
# Processing Record 36 of Set 7 : shimoda
# Processing Record 37 of Set 7 : petropavlivka
# Processing Record 38 of Set 7 : sabang
# Processing Record 39 of Set 7 : dingzhou
# Processing Record 40 of Set 7 : havoysund
# Processing Record 41 of Set 7 : weihe
# Processing Record 42 of Set 7 : aklera
# Processing Record 43 of Set 7 : berlevag
# Processing Record 44 of Set 7 : codrington
# Processing Record 45 of Set 7 : tabuk
# City not found. Skipping to next one.
# Processing Record 46 of Set 7 : aklavik
# Processing Record 47 of Set 7 : punalur
# Processing Record 48 of Set 7 : vao
# Processing Record 49 of Set 7 : mount isa
# Processing Record 50 of Set 7 : isugod
# Processing Record 0 of Set 8 : inta
# Processing Record 1 of Set 8 : tarko-sale
# Processing Record 2 of Set 8 : muhlhausen
# Processing Record 3 of Set 8 : heide
# Processing Record 4 of Set 8 : matara
# Processing Record 5 of Set 8 : bilma
# City not found. Skipping to next one.
# Processing Record 6 of Set 8 : ca mau
# Processing Record 7 of Set 8 : ereymentau
# Processing Record 8 of Set 8 : havre
# Processing Record 9 of Set 8 : teguldet
# City not found. Skipping to next one.
# Processing Record 10 of Set 8 : tombouctou
# Processing Record 11 of Set 8 : baruun-urt
# Processing Record 12 of Set 8 : ahipara
# Processing Record 13 of Set 8 : mandalgovi
# City not found. Skipping to next one.
# Processing Record 14 of Set 8 : abu samrah
# Processing Record 15 of Set 8 : finschhafen
# Processing Record 16 of Set 8 : cayenne
# Processing Record 17 of Set 8 : palmer
# Processing Record 18 of Set 8 : mazagao
# Processing Record 19 of Set 8 : kokkola
# Processing Record 20 of Set 8 : eenhana
# Processing Record 21 of Set 8 : dunedin
# Processing Record 22 of Set 8 : sisimiut
# Processing Record 23 of Set 8 : sakaiminato
# Processing Record 24 of Set 8 : port antonio
# City not found. Skipping to next one.
# Processing Record 25 of Set 8 : vanimo
# Processing Record 26 of Set 8 : pelotas
# Processing Record 27 of Set 8 : broken hill
# Processing Record 28 of Set 8 : pingzhuang
# Processing Record 29 of Set 8 : santa barbara
# Processing Record 30 of Set 8 : tonala
# Processing Record 31 of Set 8 : mayor pablo lagerenza
# Processing Record 32 of Set 8 : suratgarh
# Processing Record 33 of Set 8 : ternate
# Processing Record 34 of Set 8 : lalmohan
# Processing Record 35 of Set 8 : bengkulu
# Processing Record 36 of Set 8 : honiara
# Processing Record 37 of Set 8 : revuca
# Processing Record 38 of Set 8 : praia da vitoria
# Processing Record 39 of Set 8 : vardo
# Processing Record 40 of Set 8 : huarmey
# Processing Record 41 of Set 8 : bathsheba
# Processing Record 42 of Set 8 : pozo colorado
# Processing Record 43 of Set 8 : khani
# Processing Record 44 of Set 8 : arifwala
# Processing Record 45 of Set 8 : prince george
# Processing Record 46 of Set 8 : batagay
# Processing Record 47 of Set 8 : springbok
# Processing Record 48 of Set 8 : quatre cocos
# Processing Record 49 of Set 8 : mehamn
# Processing Record 50 of Set 8 : el alto
# Processing Record 0 of Set 9 : simao
# Processing Record 1 of Set 9 : namatanai
# Processing Record 2 of Set 9 : vestmannaeyjar
# Processing Record 3 of Set 9 : samarai
# Processing Record 4 of Set 9 : miles city
# Processing Record 5 of Set 9 : southbridge
# Processing Record 6 of Set 9 : aksarka
# Processing Record 7 of Set 9 : oktyabrskiy
# Processing Record 8 of Set 9 : madimba
# Processing Record 9 of Set 9 : zig
# City not found. Skipping to next one.
# Processing Record 10 of Set 9 : ketchikan
# Processing Record 11 of Set 9 : rio gallegos
# Processing Record 12 of Set 9 : mago
# Processing Record 13 of Set 9 : ixtapa
# Processing Record 14 of Set 9 : naantali
# Processing Record 15 of Set 9 : almeirim
# Processing Record 16 of Set 9 : peleduy
# Processing Record 17 of Set 9 : sechura
# Processing Record 18 of Set 9 : lagos
# Processing Record 19 of Set 9 : shepsi
# Processing Record 20 of Set 9 : padang
# Processing Record 21 of Set 9 : haines junction
# Processing Record 22 of Set 9 : east london
# Processing Record 23 of Set 9 : egvekinot
# Processing Record 24 of Set 9 : beberibe
# Processing Record 25 of Set 9 : kenora
# City not found. Skipping to next one.
# Processing Record 26 of Set 9 : tilichiki
# Processing Record 27 of Set 9 : kovdor
# Processing Record 28 of Set 9 : zunyi
# Processing Record 29 of Set 9 : vagur
# Processing Record 30 of Set 9 : ilhabela
# Processing Record 31 of Set 9 : cacheu
# Processing Record 32 of Set 9 : praia
# Processing Record 33 of Set 9 : yumbe
# Processing Record 34 of Set 9 : porbandar
# Processing Record 35 of Set 9 : tiksi
# Processing Record 36 of Set 9 : guerrero negro
# City not found. Skipping to next one.
# Processing Record 37 of Set 9 : tabas
# Processing Record 38 of Set 9 : kyrylivka
# Processing Record 39 of Set 9 : goryachiy klyuch
# Processing Record 40 of Set 9 : salalah
# Processing Record 41 of Set 9 : la ronge
# Processing Record 42 of Set 9 : lena
# Processing Record 43 of Set 9 : tezpur
# Processing Record 44 of Set 9 : margate
# Processing Record 45 of Set 9 : lac du bonnet
# Processing Record 46 of Set 9 : requena
# Processing Record 47 of Set 9 : oranjestad
# Processing Record 48 of Set 9 : vila velha
# Processing Record 49 of Set 9 : pitsunda
# Processing Record 50 of Set 9 : salinopolis
# Processing Record 0 of Set 10 : shingu
# Processing Record 1 of Set 10 : kendari
# Processing Record 2 of Set 10 : choya
# Processing Record 3 of Set 10 : doha
# Processing Record 4 of Set 10 : georgiyevka
# Processing Record 5 of Set 10 : high prairie
# Processing Record 6 of Set 10 : yuli
# Processing Record 7 of Set 10 : kudahuvadhoo
# Processing Record 8 of Set 10 : tura
# City not found. Skipping to next one.
# Processing Record 9 of Set 10 : liverpool
# City not found. Skipping to next one.
# Processing Record 10 of Set 10 : saint george
# Processing Record 11 of Set 10 : madang
# Processing Record 12 of Set 10 : eunice
# Processing Record 13 of Set 10 : adrar
# City not found. Skipping to next one.
# Processing Record 14 of Set 10 : kjollefjord
# Processing Record 15 of Set 10 : maneadero
# Processing Record 16 of Set 10 : pisco
# Processing Record 17 of Set 10 : tigil
# Processing Record 18 of Set 10 : swan hill
# Processing Record 19 of Set 10 : scottsboro
# Processing Record 20 of Set 10 : qui nhon
# Processing Record 21 of Set 10 : kryvyy rih
# Processing Record 22 of Set 10 : pangody
# Processing Record 23 of Set 10 : kumluca
# City not found. Skipping to next one.
# Processing Record 24 of Set 10 : biak
# Processing Record 25 of Set 10 : kabalo
# Processing Record 26 of Set 10 : tambo grande
# Processing Record 27 of Set 10 : tete
# Processing Record 28 of Set 10 : gatton
# Processing Record 29 of Set 10 : hualmay
# Processing Record 30 of Set 10 : beloha
# Processing Record 31 of Set 10 : imeni poliny osipenko
# Processing Record 32 of Set 10 : ayna
# Processing Record 33 of Set 10 : dwarka
# Processing Record 34 of Set 10 : waingapu
# Processing Record 35 of Set 10 : puerto lleras
# City not found. Skipping to next one.
# Processing Record 36 of Set 10 : resistencia
# Processing Record 37 of Set 10 : bjornevatn
# Processing Record 38 of Set 10 : soe
# Processing Record 39 of Set 10 : riyadh
# Processing Record 40 of Set 10 : atbasar
# City not found. Skipping to next one.
# Processing Record 41 of Set 10 : opuwo
# Processing Record 42 of Set 10 : paciran
# Processing Record 43 of Set 10 : tyachiv
# Processing Record 44 of Set 10 : zverinogolovskoye
# Processing Record 45 of Set 10 : raga
# Processing Record 46 of Set 10 : primorsk
# City not found. Skipping to next one.
# Processing Record 47 of Set 10 : carutapera
# Processing Record 48 of Set 10 : yagodnoye
# Processing Record 49 of Set 10 : richards bay
# Processing Record 50 of Set 10 : tamluk
# Processing Record 0 of Set 11 : faya
# Processing Record 1 of Set 11 : da lat
# Processing Record 2 of Set 11 : xining
# Processing Record 3 of Set 11 : dafeng
# Processing Record 4 of Set 11 : lancaster
# Processing Record 5 of Set 11 : tucupita
# Processing Record 6 of Set 11 : jacksonville
# Processing Record 7 of Set 11 : owando
# Processing Record 8 of Set 11 : svetlogorsk
# Processing Record 9 of Set 11 : narsaq
# Processing Record 10 of Set 11 : hukuntsi
# Processing Record 11 of Set 11 : phuket
# Processing Record 12 of Set 11 : solnechnyy
# Processing Record 13 of Set 11 : kirovskiy
# Processing Record 14 of Set 11 : christchurch
# Processing Record 15 of Set 11 : puerto boyaca
# Processing Record 16 of Set 11 : yenagoa
# Processing Record 17 of Set 11 : kazlu ruda
# Processing Record 18 of Set 11 : daru
# Processing Record 19 of Set 11 : los algarrobos
# Processing Record 20 of Set 11 : zheleznodorozhnyy
# City not found. Skipping to next one.
# Processing Record 21 of Set 11 : roald
# Processing Record 22 of Set 11 : jumla
# Processing Record 23 of Set 11 : agadir
# Processing Record 24 of Set 11 : prince rupert
# Processing Record 25 of Set 11 : yulara
# Processing Record 26 of Set 11 : sao felix do xingu
# Processing Record 27 of Set 11 : kolyvan
# Processing Record 28 of Set 11 : cairns
# Processing Record 29 of Set 11 : manica
# Processing Record 30 of Set 11 : iracoubo
# Processing Record 31 of Set 11 : korsakov
# Processing Record 32 of Set 11 : winslow
# Processing Record 33 of Set 11 : okhotsk
# Processing Record 34 of Set 11 : hohhot
# Processing Record 35 of Set 11 : kletskaya
# Processing Record 36 of Set 11 : kondopoga
# Processing Record 37 of Set 11 : teacapan
# Processing Record 38 of Set 11 : flinders
# Processing Record 39 of Set 11 : kulhudhuffushi
# Processing Record 40 of Set 11 : vila franca do campo
# Processing Record 41 of Set 11 : shymkent
# Processing Record 42 of Set 11 : tanout
# Processing Record 43 of Set 11 : bar harbor
# Processing Record 44 of Set 11 : kolda
# Processing Record 45 of Set 11 : leshukonskoye
# City not found. Skipping to next one.
# Processing Record 46 of Set 11 : marquette
# Processing Record 47 of Set 11 : catamarca
# Processing Record 48 of Set 11 : mawlaik
# Processing Record 49 of Set 11 : srivardhan
# City not found. Skipping to next one.
# Processing Record 50 of Set 11 : mendi
# Processing Record 0 of Set 12 : kayerkan
# Processing Record 1 of Set 12 : natal
# Processing Record 2 of Set 12 : aksu
# Processing Record 3 of Set 12 : tiarei
# Processing Record 4 of Set 12 : port pirie
# Processing Record 5 of Set 12 : peniche
# Processing Record 6 of Set 12 : paamiut
# Processing Record 7 of Set 12 : nemuro
# Processing Record 8 of Set 12 : mataram
# Processing Record 9 of Set 12 : orumiyeh
# City not found. Skipping to next one.
# Processing Record 10 of Set 12 : koroni
# Processing Record 11 of Set 12 : maniitsoq
# Processing Record 12 of Set 12 : santa lucia
# Processing Record 13 of Set 12 : hongjiang
# Processing Record 14 of Set 12 : ardakan
# Processing Record 15 of Set 12 : stornoway
# Processing Record 16 of Set 12 : sidrolandia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({ 
                "City" : city_name,
                "Cloudiness" : cloudiness,
                "Country" : countries,
                "Date" : date,
                "Humidity" : humidity,
                "Lat" : lat,
                "Lng" : lng_list,
                "Max Temp" : temp,
                "Wind Speed" : wind_speed
})
weather_df
# Out:
#             City  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0        Ushuaia          75      AR  1627236302       100 -54.8000  -68.3000
# 1         Albany          94      US  1627236427        74  42.6001  -73.9662
# 2      Busselton          44      AU  1627236428        66 -33.6500  115.3333
# 3           Naze         100      JP  1627236428        88  28.3667  129.4833
# 4          Gimli          18      CA  1627236428        33  50.6336  -96.9907
# ..           ...         ...     ...         ...       ...      ...       ...
# 572  Santa Lucía          20      ES  1627236585        65  27.9117  -15.5407
# 573    Hongjiang           0      CN  1627236585        94  27.1100  109.9956
# 574      Ardakān           0      IR  1627236586        10  32.3100   54.0175
# 575    Stornoway          53      GB  1627236586        82  58.2093   -6.3865
# 576  Sidrolândia           0      BR  1627236586        22 -20.9319  -54.9614
#
#      Max Temp  Wind Speed
# 0       33.46       21.85
# 1       81.27        6.62
# 2       58.08       19.44
# 3       77.97       18.72
# 4       84.43       16.13
# ..        ...         ...
# 572     69.12       29.93
# 573     73.72        0.54
# 574     97.18        6.38
# 575     62.92       10.36
# 576     90.39        8.81
#
# [577 rows x 9 columns]

# %%
weather_df.to_csv("output_data/cities.csv", index = False)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create Latitude vs. Temperature Plot scatter plot
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], facecolor = "blue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Max Temperature (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Max Temperature (F)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("Images/City Latitude vs Max Temperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create Latitude vs. Humidity Plot scatter plot
plt.scatter(weather_df["Lat"], weather_df["Humidity"], facecolor = "blue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Humidity")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Humidity (%)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("Images/City Latitude vs Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create Latitude vs. Cloudiness Plot scatter plot
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], facecolor = "blue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Cloudiness")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Cloudiness (%)")

# Set y axis limit
plt.ylim(-5,105)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("Images/City Latitude vs Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create Latitude vs. Wind Speed scatter plot
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], facecolor = "blue", edgecolor = "black")

#Set title
plt.title("City Latitude vs. Wind Speed (mph)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Wind Speed (%)")

# Set y axis limit
plt.ylim(-2,50)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("Images/City Latitude vs Wind Speed (mph).png")

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
n_hem = weather_df.loc[weather_df["Lat"] >= 0]
s_hem = weather_df.loc[weather_df["Lat"] < 0]

# Define function for creating linear agression and scatter plot
def lin_reg(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def notes(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")
    

# Call an function #1
equation = lin_reg(n_hem["Lat"], n_hem["Max Temp"])

# Call an function #2
notes(equation, 0, 0)

# Set a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude - Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.7

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = lin_reg(s_hem["Lat"],s_hem["Max Temp"])

# Call an function #2
notes(equation, -30, 50)

# Set a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.75

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = lin_reg(n_hem["Lat"], n_hem["Humidity"])

# Call an function #2
notes(equation, 40, 15)

# Set a title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("Images/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.1

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = lin_reg(s_hem["Lat"], s_hem["Humidity"])

# Call an function #2
notes(equation, -40, 50)

# Set title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("Images/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.05

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = lin_reg(n_hem["Lat"], n_hem["Cloudiness"])

# Call an function #2
notes(equation, 30, 40)

# Set a title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("Images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.01

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = lin_reg(s_hem["Lat"], s_hem["Cloudiness"])

# Call an function #2
notes(equation, -30, 40)

# Set a title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("Images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.2

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = lin_reg(n_hem["Lat"], n_hem["Wind Speed"])

# Call an function #2
notes(equation, 40, 20)

# Set  title
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("Images/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.04

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = lin_reg(s_hem["Lat"], s_hem["Wind Speed"])

# Call an function #2
notes(equation, -30, 15)

# Set  title
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.29
